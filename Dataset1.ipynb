# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("C:/Users/admin/OneDrive/Desktop/DSBDA/DSBDA NEW.csv")

# %%
df
# Out:
#     Math Score  Reading Score  Writing Score  Placement Score  Club Join  \
# 0           72             87             67               87       2021
# 1           80             89             74               83       2020
# 2           75             83             67               81       2024
# 3           60             89             78               83       2022
# 4           77             90             68               85       2022
# 5           73             88             70               95       2024
# 6           75             83             79               77       2022
# 7           76             94             78               83       2021
# 8           75             76             78               94       2021
# 9           62             91             69               89       2023
# 10          70             85             65               87       2022
# 11          77             76             77               92       2022
# ...

# %%
print(df.head(4))
# Out:
#    Math Score  Reading Score  Writing Score  Placement Score  Club Join  \
# 0          72             87             67               87       2021
# 1          80             89             74               83       2020
# 2          75             83             67               81       2024
# 3          60             89             78               83       2022
#
#    Placement Offer
# 0                3
# 1                2
# 2                2
# 3                2

# %%
print(df.info(3))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Math Score       50 non-null     int64
#  1   Reading Score    50 non-null     int64
#  2   Writing Score    50 non-null     int64
#  3   Placement Score  50 non-null     int64
#  4   Club Join        50 non-null     int64
#  5   Placement Offer  50 non-null     int64
# dtypes: int64(6)
# memory usage: 2.5 KB
# None

# %%
print(df.describe())
# Out:
#        Math Score  Reading Score  Writing Score  Placement Score    Club Join  \
# count   50.000000      50.000000      50.000000        50.000000    50.000000
# mean    70.860000      85.460000      70.780000        85.980000  2022.120000
# std      6.220473       5.715036       6.045035         6.069294     1.451811
# min     60.000000      76.000000      60.000000        75.000000  2020.000000
# 25%     65.250000      80.250000      66.250000        82.250000  2021.000000
# 50%     73.000000      85.500000      71.000000        87.000000  2022.000000
# 75%     76.000000      90.000000      77.000000        91.000000  2023.000000
# max     80.000000      94.000000      80.000000        95.000000  2024.000000
#
#        Placement Offer
# count        50.000000
# mean          2.580000
# std           0.498569
# min           2.000000
# 25%           2.000000
# 50%           3.000000
# 75%           3.000000
# max           3.000000

# %%
df.isnull()
# Out:
#     Math Score  Reading Score  Writing Score  Placement Score  Club Join  \
# 0        False          False          False            False      False
# 1        False          False          False            False      False
# 2        False          False          False            False      False
# 3        False          False          False            False      False
# 4        False          False          False            False      False
# 5        False          False          False            False      False
# 6        False          False          False            False      False
# 7        False          False          False            False      False
# 8        False          False          False            False      False
# 9        False          False          False            False      False
# 10       False          False          False            False      False
# 11       False          False          False            False      False
# ...

# %%
series=pd.isnull(df["Math Score"])

# %%
print(df.columns)
# Out:
# Index(['Math Score', 'Reading Score', 'Writing Score', 'Placement Score',
#        'Club Join', 'Placement Offer'],
#       dtype='object')

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("C:/Users/admin/OneDrive/Desktop/DSBDA/DSBDA NEW.csv")

# %%
df
# Out:
#     Math Score  Reading Score  Writing Score  Placement Score  Club Join  \
# 0           72             87             67               87       2021
# 1           80             89             74               83       2020
# 2           75             83             67               81       2024
# 3           60             89             78               83       2022
# 4           77             90             68               85       2022
# 5           73             88             70               95       2024
# 6           75             83             79               77       2022
# 7           76             94             78               83       2021
# 8           75             76             78               94       2021
# 9           62             91             69               89       2023
# 10          70             85             65               87       2022
# 11          77             76             77               92       2022
# ...

# %%
df.notnull()
# Out:
#     Math Score  Reading Score  Writing Score  Placement Score  Club Join  \
# 0         True           True           True             True       True
# 1         True           True           True             True       True
# 2         True           True           True             True       True
# 3         True           True           True             True       True
# 4         True           True           True             True       True
# 5         True           True           True             True       True
# 6         True           True           True             True       True
# 7         True           True           True             True       True
# 8         True           True           True             True       True
# 9         True           True           True             True       True
# 10        True           True           True             True       True
# 11        True           True           True             True       True
# ...

# %%
series1=pd.notnull(df["Math Score"])

# %%
df[series1]
# Out:
#     Math Score  Reading Score  Writing Score  Placement Score  Club Join  \
# 0           72             87             67               87       2021
# 1           80             89             74               83       2020
# 2           75             83             67               81       2024
# 3           60             89             78               83       2022
# 4           77             90             68               85       2022
# 5           73             88             70               95       2024
# 6           75             83             79               77       2022
# 7           76             94             78               83       2021
# 8           75             76             78               94       2021
# 9           62             91             69               89       2023
# 10          70             85             65               87       2022
# 11          77             76             77               92       2022
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['Math Score']=le.fit_transform(df['Math Score'])

# %%
newdf=df

# %% [markdown]
# missing_values=["Na", "Na"]

# %%
missing_values=["na", "Na"]
df = pd.read_csv("C:/Users/admin/OneDrive/Desktop/DSBDA/DSBDA NEW.csv",na_values=missing_values)

# %%
df
# Out:
#     Math Score  Reading Score  Writing Score  Placement Score  Club Join  \
# 0           72             87             67               87       2021
# 1           80             89             74               83       2020
# 2           75             83             67               81       2024
# 3           60             89             78               83       2022
# 4           77             90             68               85       2022
# 5           73             88             70               95       2024
# 6           75             83             79               77       2022
# 7           76             94             78               83       2021
# 8           75             76             78               94       2021
# 9           62             91             69               89       2023
# 10          70             85             65               87       2022
# 11          77             76             77               92       2022
# ...

# %%
ndf=df

# %%
ndf.fillna(0)
# Out:
#     Math Score  Reading Score  Writing Score  Placement Score  Club Join  \
# 0           72             87             67               87       2021
# 1           80             89             74               83       2020
# 2           75             83             67               81       2024
# 3           60             89             78               83       2022
# 4           77             90             68               85       2022
# 5           73             88             70               95       2024
# 6           75             83             79               77       2022
# 7           76             94             78               83       2021
# 8           75             76             78               94       2021
# 9           62             91             69               89       2023
# 10          70             85             65               87       2022
# 11          77             76             77               92       2022
# ...

# %%
column=["Math Score","Reading Score","Writing Score"]

# %%
df.boxplot(column)
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: >
